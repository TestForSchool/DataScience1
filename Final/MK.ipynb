# %%
#Loads Spreadsheets
import pandas as pd

# Load data from CSV files into separate DataFrames
body_stats_df = pd.read_csv('MarioKartBodyStats.csv')
driver_stats_df = pd.read_csv('MarioKartDriverStats.csv')
glider_stats_df = pd.read_csv('MarioKartGliderStats.csv')
wheel_stats_df = pd.read_csv('MarioKartWheelStats.csv')

# %%
body_stats_df.head()
# Out:
#            Vehicle  Type  Weight  Acceleration  On-Road_Traction  \
# 0  300 SL Roadster  Kart       2             4                 3
# 1         B Dasher  Kart       3             1                 3
# 2         Badwagon  Kart       4             0                 2
# 3       Biddybuggy  Kart       0             7                 1
# 4      Blue Falcon  Kart       0             3                 1
#
#    Off-Road Traction  Mini-Turbo  Ground_Speed  Water_Speed  \
# 0                  3           4             3            3
# 1                  1           1             5            1
# 2                  5           0             5            2
# 3                  4           7             0            1
# 4                  3           3             4            2
#
#    Anti-Gravity_Speed  Air_Speed  Ground_Handling  Water Handling  \
# 0                   3          3                3               2
# 1                   4          2                1               1
# 2                   3          1                0               1
# 3                   2          1                5               4
# 4                   4          3                2               3
#
#    Anti-Gravity_Handling  Air_Handling
# 0                      3             3
# 1                      2             0
# 2                      1             0
# 3                      5             4
# 4                      5             1

# %%
col = body_stats_df['Acceleration'] + body_stats_df['Ground_Speed']
body_stats_df["New"] = col

# %%
body_stats_df.head()
# Out:
#            Vehicle  Type  Weight  Acceleration  On-Road_Traction  \
# 0  300 SL Roadster  Kart       2             4                 3
# 1         B Dasher  Kart       3             1                 3
# 2         Badwagon  Kart       4             0                 2
# 3       Biddybuggy  Kart       0             7                 1
# 4      Blue Falcon  Kart       0             3                 1
#
#    Off-Road Traction  Mini-Turbo  Ground_Speed  Water_Speed  \
# 0                  3           4             3            3
# 1                  1           1             5            1
# 2                  5           0             5            2
# 3                  4           7             0            1
# 4                  3           3             4            2
#
#    Anti-Gravity_Speed  Air_Speed  Ground_Handling  Water Handling  \
# 0                   3          3                3               2
# 1                   4          2                1               1
# 2                   3          1                0               1
# 3                   2          1                5               4
# 4                   4          3                2               3
#
#    Anti-Gravity_Handling  Air_Handling  New
# 0                      3             3    7
# 1                      2             0    6
# 2                      1             0    5
# 3                      5             4    7
# 4                      5             1    7

# %%
print (body_stats_df)
# Out:
#               Vehicle           Type  Weight  Acceleration  On-Road_Traction  \
# 0     300 SL Roadster           Kart       2             4                 3
# 1            B Dasher           Kart       3             1                 3
# 2            Badwagon           Kart       4             0                 2
# 3          Biddybuggy           Kart       0             7                 1
# 4         Blue Falcon           Kart       0             3                 1
# 5        Bone Rattler            ATV       4             1                 1
# 6         Cat Cruiser           Kart       2             5                 4
# 7     Circuit Special           Kart       3             1                 3
# 8        City Tripper  Standard Bike       1             6                 3
# 9               Comet     Sport Bike       2             5                 4
# 10        Flame Rider  Standard Bike       1             5                 3
# 11                GLA           Kart       4             0                 2
# 12      Gold Standard           Kart       2             2                 1
# 13         Inkstriker            ATV       3             3                 2
# 14           Jet Bike     Sport Bike       1             2                 1
# 15        Koopa Clown           Kart       3             2                 4
# 16           Landship           Kart       0             6                 0
# 17             Mach 8           Kart       3             3                 2
# 18       Master Cycle     Sport Bike       2             2                 1
# 19  Master Cycle Zero  Standard Bike       3             2                 4
# 20         Mr. Scooty  Standard Bike       0             7                 1
# 21             P-Wing           Kart       3             1                 3
# 22         Pipe Frame           Kart       1             6                 3
# 23            Prancer           Kart       1             2                 1
# 24            Sneeker           Kart       2             2                 1
# 25        Splat Buggy            ATV       0             3                 1
# 26         Sport Bike     Sport Bike       1             2                 1
# 27       Sports Coupe           Kart       3             3                 2
# 28       Standard ATV            ATV       4             0                 2
# 29      Standard Bike  Standard Bike       1             5                 3
# 30      Standard Kart           Kart       2             4                 3
# 31       Steel Driver           Kart       4             1                 1
# 32           Streetle           Kart       0             6                 0
# 33       Tanooki Kart           Kart       3             2                 4
# 34        Teddy Buggy            ATV       2             5                 4
# 35           The Duke  Standard Bike       2             4                 3
# 36        Tri-Speeder           Kart       4             1                 1
# 37            Varmint  Standard Bike       1             6                 3
# 38  W 25 Silver Arrow           Kart       1             5                 3
# 39       Wild Wiggler            ATV       1             5                 3
# 40         Yoshi Bike     Sport Bike       2             5                 4
#
#     Off-Road Traction  Mini-Turbo  Ground_Speed  Water_Speed  \
# 0                   3           4             3            3
# 1                   1           1             5            1
# 2                   5           0             5            2
# 3                   4           7             0            1
# 4                   3           3             4            2
# 5                   3           2             4            5
# 6                   3           5             2            2
# 7                   1           1             5            1
# 8                   4           6             1            3
# 9                   3           5             2            2
# 10                  5           5             2            2
# 11                  5           0             5            2
# 12                  0           3             4            2
# 13                  4           4             3            3
# 14                  2           3             4            3
# 15                  7           3             2            4
# 16                  6           6             1            5
# 17                  4           4             3            3
# 18                  0           3             4            2
# 19                  7           3             2            4
# 20                  4           7             0            1
# 21                  1           1             5            1
# 22                  4           6             1            3
# 23                  2           3             4            3
# 24                  0           3             4            2
# 25                  3           3             4            2
# 26                  2           3             4            3
# 27                  4           4             3            3
# 28                  5           0             5            2
# 29                  5           5             2            2
# 30                  3           4             3            3
# 31                  3           2             4            5
# 32                  6           6             1            5
# 33                  7           3             2            4
# 34                  3           5             2            2
# 35                  3           4             3            3
# 36                  3           2             4            5
# 37                  4           6             1            3
# 38                  5           5             2            2
# 39                  5           5             2            2
# 40                  3           5             2            2
#
#     Anti-Gravity_Speed  Air_Speed  Ground_Handling  Water Handling  \
# 0                    3          3                3               2
# 1                    4          2                1               1
# 2                    3          1                0               1
# 3                    2          1                5               4
# 4                    4          3                2               3
# 5                    2          0                1               5
# 6                    3          4                4               2
# 7                    4          2                1               1
# 8                    1          1                5               4
# 9                    3          4                4               2
# 10                   4          3                4               3
# 11                   3          1                0               1
# 12                   3          3                3               2
# 13                   5          4                2               2
# 14                   3          3                3               3
# 15                   3          3                4               4
# 16                   0          2                4               5
# 17                   5          4                2               2
# 18                   3          3                3               2
# 19                   3          3                4               4
# 20                   2          1                5               4
# 21                   4          2                1               1
# 22                   1          1                5               4
# 23                   3          3                3               3
# 24                   3          3                3               2
# 25                   4          3                2               3
# 26                   3          3                3               3
# 27                   5          4                2               2
# 28                   3          1                0               1
# 29                   4          3                4               3
# 30                   3          3                3               2
# 31                   2          0                1               5
# 32                   0          2                4               5
# 33                   3          3                4               4
# 34                   3          4                4               2
# 35                   3          3                3               2
# 36                   2          0                1               5
# 37                   1          1                5               4
# 38                   4          3                4               3
# 39                   4          3                4               3
# 40                   3          4                4               2
#
#     Anti-Gravity_Handling  Air_Handling
# 0                       3             3
# 1                       2             0
# 2                       1             0
# 3                       5             4
# 4                       5             1
# 5                       1             1
# 6                       3             4
# 7                       2             0
# 8                       4             2
# 9                       3             4
# 10                      4             3
# 11                      1             0
# 12                      3             2
# 13                      4             2
# 14                      2             3
# 15                      3             3
# 16                      2             3
# 17                      4             2
# 18                      3             2
# 19                      3             3
# 20                      5             4
# 21                      2             0
# 22                      4             2
# 23                      2             3
# 24                      3             2
# 25                      5             1
# 26                      2             3
# 27                      4             2
# 28                      1             0
# 29                      4             3
# 30                      3             3
# 31                      1             1
# 32                      2             3
# 33                      3             3
# 34                      3             4
# 35                      3             3
# 36                      1             1
# 37                      4             2
# 38                      4             3
# 39                      4             3
# 40                      3             4

# %%
# Adds Speed+Acceleration
body_stats_df['total_speed_acceleration'] = body_stats_df['Ground_Speed'] + body_stats_df['Acceleration']
sorted_body_stats_df = body_stats_df.sort_values(by='total_speed_acceleration', ascending=False)
print(sorted_body_stats_df[['name', 'total_speed_acceleration']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ground_Speed'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13604\4261809073.py in <module>
#       1 # Adds Speed+Acceleration
# ----> 2 body_stats_df['total_speed_acceleration'] = body_stats_df['Ground_Speed'] + body_stats_df['Acceleration']
#       3 sorted_body_stats_df = body_stats_df.sort_values(by='total_speed_acceleration', ascending=False)
#       4 print(sorted_body_stats_df[['name', 'total_speed_acceleration']])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Ground_Speed'
